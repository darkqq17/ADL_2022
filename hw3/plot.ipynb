# %%
import matplotlib.pyplot as plt

x_1 = [1000, 2000, 3000, 4000, 5000, 6000, 6500]
y_1 = [0.2203,0.2331,0.2434,0.2478,0.2520,0.2556,0.2572]
plt.plot(x_1,y_1)
plt.title("train/rouge-1_f")
plt.show()

y_2 = [0.0855,0.0905,0.0963,0.1004,0.1004,0.1038,0.1040]
plt.plot(x_1,y_2)
plt.title("train/rouge-2_f")
plt.show()

y_3 = [0.2026,0.2123,0.2209,0.2250,0.2275,0.2313,0.2328]
plt.plot(x_1,y_3)
plt.title("train/rouge-l_f")
plt.show()

y_p_1 = [0.2889,0.2870,0.3036,0.3023,0.3010,0.3029,0.3063]
plt.plot(x_1,y_p_1)
plt.title("train/rouge-1_p")
plt.show()

y_p_2 = [0.1097,0.1101,0.1196,0.1225,0.1196,0.1233,0.1239]
plt.plot(x_1,y_p_2)
plt.title("train/rouge-2_p")
plt.show()

y_p_3 = [0.2663,0.2614,0.2755,0.2744,0.2712,0.2737,0.2769]
plt.plot(x_1,y_p_3)
plt.title("train/rouge-l_p")
plt.show()

y_r_1 = [0.1891,0.2076,0.2140,0.2206,0.2273,0.2313,0.2318]
plt.plot(x_1,y_r_1)
plt.title("train/rouge-1_r")
plt.show()

y_r_2 = [0.0747,0.0812,0.0851,0.0893,0.0906,0.0939,0.0939]
plt.plot(x_1,y_r_2)
plt.title("train/rouge-2_r")
plt.show()

y_r_3 = [0.1746,0.1892,0.1944,0.2005,0.2056,0.2097,0.2104]
plt.plot(x_1,y_r_3)
plt.title("train/rouge-l_r")
plt.show()
